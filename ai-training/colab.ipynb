# %% [markdown]
# # AI-Genomic-Surveillance — Colab Starter
#
# This notebook mounts Google Drive and runs a dry-run training using the provided scripts.
#
# Steps:
# 1. Mount Google Drive
# 2. Install requirements
# 3. Run `python train.py --dry-run`

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install -r /content/ai-training/requirements.txt

# %%
# !python /content/ai-training/train.py --dry-run
